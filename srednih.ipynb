# %% [markdown]
# Критерий проверки линий тренда.Метод средних

# %%
import pandas as pd
import numpy as np
data = pd.DataFrame({'Year':range(1,16),'Productivity':[14.1,9.3,19.4,19.7,5.4,24.2,13.8,24.5,14.7,16.6,5.6,16.2,25.3,11.9,18.5]})

# %%
data.Productivity.plot(figsize=(8,3))

# %%
data_array = np.array(data.Productivity)
count1 = 7
count2 = 8
data1=[]
data2=[]
data1 = data_array[0:count1]
data2 = data_array[count1:]

# %%
std1 = np.std(data1,ddof=1)
std2 = np.std(data2,ddof=1)

# %%
F = (std1**2) / (std2**2)

# %%
#F < Fтабл поэтому нет основания отвергарть нулевую гипотезу

# %%
t  = (abs(data1.mean()-data2.mean())*((count1*count2*(count1+count2-1))**0.5)) / (((count1-1)*(std1**2) + ((count2-1)*(std2**2)))**0.5)

# %%
t # тренда нет
# Out:
# 1.8458602354207034
